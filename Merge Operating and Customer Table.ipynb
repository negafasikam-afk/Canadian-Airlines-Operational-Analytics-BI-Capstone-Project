# %% [markdown]
# # Create a silver operational table - Merge Operational statistics tables into one table

# %%
df1 = spark.read.table("`operating profit`")
df2 = spark.read.table("`operational revenue and expense`")
df3 = spark.read.table("`operational revenue per employee`")
df4 = spark.read.table("`operational statistics`")


df1 = df1.withColumnRenamed("Date", "Date")
df2 = df2.withColumnRenamed("Date", "Date_df2")
df3 = df3.withColumnRenamed("Date", "Date_df3")
df4 = df4.withColumnRenamed("Date", "Date_df4")
# Align schemas (optional but often needed)
common_col = "ID" 

merged_df_new = (
    df1
    .join(df2, on=common_col, how="left")
    .join(df3, on=common_col, how="left")
    .join(df4, on=common_col, how="left")
)
merged_df_new.show()
# Out:
# StatementMeta(, 2c497fca-bdb2-4efb-b199-544de5641ead, 10, Finished, Available, Finished)
# +---+-------+-----------------+-------------------------+----------------+--------+------------------------------------+---------------------------------------------------------------------+--------------------------------------+----------------------------------+------------------------------------+----------------------------+-----------------------------+--------+------------------------------+-----------------------------------+--------+-----------------------------+----------------------------+----------------------------------+---------------------------------------+-------------------------------------+---------------------------------+---------------------------------+----------------------+
# | ID|  Date_|Operating ratio 8|Operating profit margin 9|Profit margin 10|Date_df2|Total_ scheduled services  _x 1_000_|Total_ operating revenue_ scheduled and charter services  _x 1_000_/$|All other operating revenue  _x 1_000_|Total_ charter services  _x 1_000_|Total_ operating expenses  _x 1_000_|Net income _loss_  _x 1_000_|Average number of employees 8|Date_df3|Operating revenue per employee|Tonne-kilometres flown per employee|Date_df4|Number of carriers included 8|Passengers  _x 1_000_/number|Goods carried  _x 1_000_/Kilograms|Passenger-kilometres  _x 1_000_/Numbers|Passenger tonne-kilometres  _x 1_000_|Goods tonne-kilometres  _x 1_000_|Total tonne-kilometres  _x 1_000_|Hours flown  _x 1_000_|
# +---+-------+-----------------+-------------------------+----------------+--------+------------------------------------+---------------------------------------------------------------------+--------------------------------------+----------------------------------+------------------------------------+----------------------------+-----------------------------+--------+------------------------------+-----------------------------------+--------+-----------------------------+----------------------------+----------------------------------+---------------------------------------+-------------------------------------+---------------------------------+---------------------------------+----------------------+
# |  1|Q1 2016|             0.95|                      4.6|             5.6| Q1 2016|                             4760128|                                                              5139315|                                228021|                            151166|                             4902219|                      288033|                        52579| Q1 2016|                         97744|                              94909| Q1 2016|                           24|                       19223|                            135986|                               44923514|                              4492351|                           497871|                          4990222|                   692|
# |  2|Q2 2016|             0.93|                      7.4|             5.7| Q2 2016|                             4755025|                                                              5221023|                                336707|                            129291|                             4835359|                      299096|                        53901| Q2 2016|                         96863|                              95240| Q2 2016|                           24|                       19429|                            147892|                               45754810|                              4575481|                           558056|                          5133537|                   707|
# |  3|Q3 2016|             0.82|                     18.3|            15.2| Q3 2016|                             6022754|                                                              6580564|                                436941|                            120869|                             5373689|                      999110|                        53555| Q3 2016|                        122874|                             120555| Q3 2016|                           24|                       22723|                            169564|                               58055686|                              5805569|                           650801|                          6456369|                   847|
# |  4|Q4 2016|             0.98|                      2.2|            -2.9| Q4 2016|                             4622242|                                                              5090793|                                336204|                            132347|                             4978643|                     -147759|                        53809| Q4 2016|                         94608|                              92758| Q4 2016|                           24|                       19067|                            162768|                               43155443|                              4315544|                           675673|                          4991217|                   704|
# |  5|Q1 2017|             0.97|                      2.5|             2.4| Q1 2017|                             5060139|                                                              5506630|                                297291|                            149200|                             5368523|                      132312|                        54082| Q1 2017|                        101820|                             102813| Q1 2017|                           26|                       20840|                            164236|                               49367112|                              4936711|                           623648|                          5560360|                   769|
# |  6|Q2 2017|             0.91|                      9.0|             7.3| Q2 2017|                             5257411|                                                              5791355|                                385798|                            148146|                             5272819|                      423764|                        55791| Q2 2017|                        103804|                             103870| Q2 2017|                           26|                       21302|                            171132|                               50943899|                              5094390|                           700606|                          5794996|                   705|
# |  7|Q3 2017|              0.8|                     19.7|            28.7| Q3 2017|                             6475767|                                                              7127706|                                490888|                            161051|                             5724002|                     2042468|                        57046| Q3 2017|                        124947|                             123579| Q3 2017|                           26|                       24218|                            178337|                               62399414|                              6239941|                           809772|                          7049714|                   804|
# |  8|Q4 2017|             0.96|                      3.6|             1.5| Q4 2017|                             5084112|                                                              5658234|                                406656|                            167467|                             5456117|                       86747|                        57192| Q4 2017|                         98934|                              95684| Q4 2017|                           26|                       20446|                            189487|                               47015064|                              4701506|                           770860|                          5472367|                   699|
# |  9|Q1 2018|             0.98|                      1.5|            -2.3| Q1 2018|                             5644999|                                                              6070935|                                265356|                            160579|                             5978823|                     -141581|                        59518| Q1 2018|                        102002|                             101070| Q1 2018|                           25|                       22027|                            172721|                               53292504|                              5329250|                           686244|                          6015495|                   722|
# | 10|Q2 2018|             0.97|                      3.4|            -1.4| Q2 2018|                             5917492|                                                              6304690|                                229076|                            158122|                             6090133|                      -88051|                        59895| Q2 2018|                        105262|                             104958| Q2 2018|                           24|                       22485|                            190121|                               55005261|                              5500526|                           785935|                          6286461|                   745|
# | 11|Q3 2018|             0.86|                     14.0|            10.5| Q3 2018|                             7262664|                                                              7772693|                                348958|                            161070|                             6682859|                      816756|                        60235| Q3 2018|                        129039|                                  0| Q3 2018|                           24|                       25683|                            192730|                               67784228|                              6778423|                                0|                                0|                   823|
# | 12|Q4 2018|             0.97|                      2.9|            -4.1| Q4 2018|                             5789422|                                                              6250059|                                307766|                            152871|                             6071397|                     -254087|                        59569| Q4 2018|                        104921|                              98568| Q4 2018|                           24|                       21311|                            196149|                               50560960|                              5056096|                           815478|                          5871574|                   716|
# | 13|Q1 2019|             0.97|                      3.2|             6.3| Q1 2019|                             6140152|                                                              6627934|                                300700|                            187082|                             6413666|                      416370|                        62812| Q1 2019|                        105520|                             101094| Q1 2019|                           26|                       23212|                            168991|                               56443809|                              5644381|                           705531|                          6349912|                   742|
# | 14|Q2 2019|             0.93|                      7.0|             6.5| Q2 2019|                             6357666|                                                              6922134|                                385241|                            179226|                             6439412|                      449264|                        62568| Q2 2019|                        110634|                             103214| Q2 2019|                           25|                       22760|                            179532|                               57230295|                              5723029|                           734841|                          6457871|                   690|
# | 15|Q3 2019|             0.84|                     16.1|            11.1| Q3 2019|                             7401434|                                                              8058442|                                469003|                            188005|                             6760075|                      895505|                        63134| Q3 2019|                        127640|                             118382| Q3 2019|                           25|                       25336|                            186947|                               66860100|                              6686010|                           787927|                          7473937|                   774|
# | 16|Q4 2019|             0.97|                      3.3|             2.1| Q4 2019|                             5961418|                                                              6525001|                                379141|                            184442|                             6312543|                      139606|                        63071| Q4 2019|                        103455|                              94976| Q4 2019|                           25|                       21595|                            186622|                               52168669|                              5216867|                           773382|                          5990249|                   693|
# | 17|Q1 2020|             1.07|                     -7.3|             0.0| Q1 2020|                             5380867|                                                              5772849|                                225700|                            166281|                             6193284|                           0|                        62316| Q1 2020|                         92638|                              86065| Q1 2020|                           25|                       19298|                            156720|                               47531166|                              4753117|                           610099|                          5363215|                   616|
# | 18|Q2 2020|             2.33|                   -133.0|          -151.6| Q2 2020|                              778875|                                                              1286320|                                158706|                            348739|                             2996685|                    -1950062|                        36826| Q2 2020|                         34930|                              16696| Q2 2020|                           25|                        1318|                            118625|                                2187926|                               218793|                           396041|                           614834|                   131|
# | 19|Q3 2020|             1.53|                    -53.0|           -41.4| Q3 2020|                             1188773|                                                              1619238|                                145588|                            284877|                             2477908|                     -670159|                        41469| Q3 2020|                         39047|                              26860| Q3 2020|                           25|                        3529|                            143516|                                6526957|                               652696|                           461178|                          1113874|                   200|
# | 20|Q4 2020|             1.58|                    -57.6|           -62.5| Q4 2020|                             1238365|                                                              1750223|                                200320|                            311210|                             2757553|                    -1094570|                        42568| Q4 2020|                         41116|                              27974| Q4 2020|                           25|                        3197|                            167577|                                6130985|                               613099|                           577701|                          1190799|                   205|
# +---+-------+-----------------+-------------------------+----------------+--------+------------------------------------+---------------------------------------------------------------------+--------------------------------------+----------------------------------+------------------------------------+----------------------------+-----------------------------+--------+------------------------------+-----------------------------------+--------+-----------------------------+----------------------------+----------------------------------+---------------------------------------+-------------------------------------+---------------------------------+---------------------------------+----------------------+
# only showing top 20 rows

# %% [markdown]
# # Cleaning the columns that have symbols like () {}

# %%
def clean_columns(df):
    import re
    new_columns = []
    for c in merged_df_new.columns:
        # 1. Remove leading/trailing spaces
        new_c = c.strip()
        # 2. Replace spaces and special characters with underscore
        new_c = re.sub(r'[ ,;{}()\n\t=/$]', '_', new_c)
        # 3. Collapse multiple underscores
        new_c = re.sub(r'_+', '_', new_c)
        # 4. Remove trailing underscores
        new_c = new_c.strip('_')
        new_columns.append(new_c)
    # Rename columns in DataFrame
    for old, new in zip(df.columns, new_columns):
        df = df.withColumnRenamed(old, new)
    return df

merged_df_new = clean_columns(merged_df_new)
# Out:
# StatementMeta(, 2c497fca-bdb2-4efb-b199-544de5641ead, 11, Finished, Available, Finished)

# %%
merged_df_new.printSchema()
print(merged_df_new.columns)
# Out:
# StatementMeta(, 2c497fca-bdb2-4efb-b199-544de5641ead, 12, Finished, Available, Finished)
# root
#  |-- ID: long (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Operating_ratio_8: double (nullable = true)
#  |-- Operating_profit_margin_9: double (nullable = true)
#  |-- Profit_margin_10: double (nullable = true)
#  |-- Date_df2: string (nullable = true)
#  |-- Total_scheduled_services_x_1_000: long (nullable = true)
#  |-- Total_operating_revenue_scheduled_and_charter_services_x_1_000: long (nullable = true)
#  |-- All_other_operating_revenue_x_1_000: long (nullable = true)
#  |-- Total_charter_services_x_1_000: long (nullable = true)
#  |-- Total_operating_expenses_x_1_000: long (nullable = true)
#  |-- Net_income_loss_x_1_000: long (nullable = true)
#  |-- Average_number_of_employees_8: long (nullable = true)
#  |-- Date_df3: string (nullable = true)
#  |-- Operating_revenue_per_employee: long (nullable = true)
#  |-- Tonne-kilometres_flown_per_employee: long (nullable = true)
#  |-- Date_df4: string (nullable = true)
#  |-- Number_of_carriers_included_8: long (nullable = true)
#  |-- Passengers_x_1_000_number: long (nullable = true)
#  |-- Goods_carried_x_1_000_Kilograms: long (nullable = true)
#  |-- Passenger-kilometres_x_1_000_Numbers: long (nullable = true)
#  |-- Passenger_tonne-kilometres_x_1_000: long (nullable = true)
#  |-- Goods_tonne-kilometres_x_1_000: long (nullable = true)
#  |-- Total_tonne-kilometres_x_1_000: long (nullable = true)
#  |-- Hours_flown_x_1_000: long (nullable = true)
#
# ['ID', 'Date', 'Operating_ratio_8', 'Operating_profit_margin_9', 'Profit_margin_10', 'Date_df2', 'Total_scheduled_services_x_1_000', 'Total_operating_revenue_scheduled_and_charter_services_x_1_000', 'All_other_operating_revenue_x_1_000', 'Total_charter_services_x_1_000', 'Total_operating_expenses_x_1_000', 'Net_income_loss_x_1_000', 'Average_number_of_employees_8', 'Date_df3', 'Operating_revenue_per_employee', 'Tonne-kilometres_flown_per_employee', 'Date_df4', 'Number_of_carriers_included_8', 'Passengers_x_1_000_number', 'Goods_carried_x_1_000_Kilograms', 'Passenger-kilometres_x_1_000_Numbers', 'Passenger_tonne-kilometres_x_1_000', 'Goods_tonne-kilometres_x_1_000', 'Total_tonne-kilometres_x_1_000', 'Hours_flown_x_1_000']

# %% [markdown]
# # Writing the updated Table to LakehouseLakehouse

# %%
merged_df_new.write.format("delta").mode("overwrite").saveAsTable("merged_operation_Silver")
# Out:
# StatementMeta(, 2c497fca-bdb2-4efb-b199-544de5641ead, 13, Finished, Available, Finished)

# %% [markdown]
# # Create Customer silver table - Merging customer loyality table

# %%
df5 = spark.read.table("`customer_flight_sliver`")
df6 = spark.read.table("`customer_loyalty_silver`")



# Align schemas (optional but often needed)
common_col = "Loyalty Number" 

merged_df_Customer = (
    df5
    .join(df6, on=common_col, how="left")
 
   
)
merged_df_Customer.show()
# Out:
# StatementMeta(, 2c497fca-bdb2-4efb-b199-544de5641ead, 14, Finished, Available, Finished)
# +--------------+----+-----+-------------+--------+------------------+---------------+---------------------------+--------------+---------------------------+---------------+----------------+--------------+-----------+------+--------------------+--------+--------------+---------------+-----------------------+---------------+----------+----------+------+------------------------+
# |Loyalty Number|Year|Month|Total Flights|Distance|Points Accumulated|Points Redeemed|Dollar Cost Points Redeemed|Points Balance|Average Distance Per Flight|Points Per Mile|        Province|          City|Postal Code|Gender|           Education|  Salary|Marital Status|Membership Tier|Customer Lifetime Value|Enrollment Type| Join Date|Leave Date|Status|Customer Tenure _Months_|
# +--------------+----+-----+-------------+--------+------------------+---------------+---------------------------+--------------+---------------------------+---------------+----------------+--------------+-----------+------+--------------------+--------+--------------+---------------+-----------------------+---------------+----------+----------+------+------------------------+
# |        219431|2018|    6|           20|   23640|           35460.0|            716|                        129|       34744.0|                     1182.0|            1.5|British Columbia|  Dawson Creek|    U5I 4F1|  Male|             College|     0.0|      Divorced|           Star|                3982.27| 2018 Promotion|2018-02-01|      NULL|Active|                   95.07|
# |        285909|2018|    6|           20|   35920|           53880.0|            743|                        134|       53137.0|                     1796.0|            1.5|British Columbia|     Vancouver|    V6E 3Z3|Female|            Bachelor| 57499.0|       Married|         Aurora|                5671.93| 2018 Promotion|2018-03-01|      NULL|Active|                   94.13|
# |        363967|2018|    6|           20|   44900|           67350.0|            515|                         93|       66835.0|                     2245.0|            1.5|         Ontario|       Trenton|    K8V 4B2|  Male|             College|     0.0|        Single|           Nova|                5568.95| 2018 Promotion|2018-04-01|      NULL|Active|                    93.1|
# |        514652|2018|    6|           20|   16780|           25170.0|            715|                        129|       24455.0|                      839.0|            1.5|British Columbia|  Dawson Creek|    U5I 4F1|  Male|            Bachelor| 70418.0|       Married|           Nova|                5206.12| 2018 Promotion|2018-04-01|      NULL|Active|                    93.1|
# |        603070|2018|    6|           20|   12620|           18930.0|            593|                        107|       18337.0|                      631.0|            1.5|British Columbia|West Vancouver|    V6V 8Z3|Female|            Bachelor|     0.0|        Single|           Star|                2893.74| 2018 Promotion|2018-03-01|      NULL|Active|                   94.13|
# |        632515|2018|    6|           20|   18120|           27180.0|            672|                        121|       26508.0|                      906.0|            1.5|British Columbia|     Vancouver|    V6E 3D9|  Male|            Bachelor| 53768.0|       Married|           Nova|                2773.46| 2018 Promotion|2018-03-01|      NULL|Active|                   94.13|
# |        634615|2018|    6|           20|   33340|           50010.0|            432|                         78|       49578.0|                     1667.0|            1.5|British Columbia|West Vancouver|    V6V 8Z3|  Male|             College|     0.0|        Single|         Aurora|               14274.55| 2018 Promotion|2018-02-01|      NULL|Active|                   95.07|
# |        797326|2018|    6|           20|   48280|           72420.0|            496|                         89|       71924.0|                     2414.0|            1.5|         Ontario|       Toronto|    M2Z 4K1|  Male|            Bachelor| 79766.0|       Married|           Star|                3942.73| 2018 Promotion|2018-04-01|      NULL|Active|                    93.1|
# |        836226|2018|    6|           20|   31380|           47070.0|            493|                         89|       46577.0|                     1569.0|            1.5|British Columbia|     Vancouver|    V6E 3Z3|  Male|High School or Below| 63114.0|       Married|           Star|                4558.43| 2018 Promotion|2018-03-01|      NULL|Active|                   94.13|
# |        869672|2018|    6|           20|   32660|           48990.0|            605|                        109|       48385.0|                     1633.0|            1.5|         Ontario|       Trenton|    K8V 4B2|Female|             College|     0.0|        Single|           Star|                 9672.7| 2018 Promotion|2018-04-01|      NULL|Active|                    93.1|
# |        875560|2018|    6|           20|   11400|           17100.0|            527|                         95|       16573.0|                      570.0|            1.5|          Quebec|          Hull|    J8Y 3Z5|Female|             College|     0.0|        Single|         Aurora|                9624.94| 2018 Promotion|2018-04-01|      NULL|Active|                    93.1|
# |        898427|2018|    6|           20|   41860|           62790.0|            736|                        132|       62054.0|                     2093.0|            1.5|    Saskatchewan|        Regina|    S1J 3C5|  Male|             College|     0.0|        Single|           Star|                7751.86| 2018 Promotion|2018-04-01|      NULL|Active|                    93.1|
# |        155020|2018|    6|           24|   17688|           26532.0|            676|                        122|       25856.0|                      737.0|            1.5|            NULL|          NULL|       NULL|  NULL|                NULL|    NULL|          NULL|           NULL|                   NULL|           NULL|      NULL|      NULL|  NULL|                    NULL|
# |        297684|2018|    6|           24|   22512|           33768.0|            723|                        130|       33045.0|                      938.0|            1.5|          Quebec|          Hull|    J8Y 3Z5|  Male|            Bachelor| 57996.0|       Married|           Nova|                2885.74| 2018 Promotion|2018-03-01|      NULL|Active|                   94.13|
# |        347227|2018|    6|           24|   26064|           39096.0|            482|                         87|       38614.0|                     1086.0|            1.5|          Quebec|      Montreal|    H2Y 4R4|Female|            Bachelor| 51890.0|        Single|           Star|                 2386.2| 2018 Promotion|2018-02-01|      NULL|Active|                   95.07|
# |        480872|2018|    6|           24|   58896|           88344.0|            679|                        122|       87665.0|                     2454.0|            1.5|British Columbia|     Vancouver|    V6E 3D9|Female|            Bachelor|104116.0|        Single|           Nova|                 2828.1| 2018 Promotion|2018-02-01|      NULL|Active|                   95.07|
# |        653304|2018|    6|           24|   46680|           70020.0|            697|                        125|       69323.0|                     1945.0|            1.5|            NULL|          NULL|       NULL|  NULL|                NULL|    NULL|          NULL|           NULL|                   NULL|           NULL|      NULL|      NULL|  NULL|                    NULL|
# |        702686|2018|    6|           24|   15432|           23148.0|            609|                        110|       22539.0|                      643.0|            1.5|British Columbia|     Vancouver|    V6E 3D9|Female|             College|     0.0|       Married|           Star|                5173.49| 2018 Promotion|2018-02-01|      NULL|Active|                   95.07|
# |        743766|2018|    6|           24|   52320|           78480.0|            478|                         86|       78002.0|                     2180.0|            1.5|          Quebec|      Montreal|    H2T 9K8|Female|            Bachelor| 52939.0|        Single|           Star|                8716.37| 2018 Promotion|2018-02-01|      NULL|Active|                   95.07|
# |        800220|2018|    6|           24|   40992|           61488.0|            690|                        124|       60798.0|                     1708.0|            1.5|         Ontario|       Toronto|    P2T 6G3|Female|            Bachelor| 31108.0|       Married|           Nova|                4049.81| 2018 Promotion|2018-03-01|      NULL|Active|                   94.13|
# +--------------+----+-----+-------------+--------+------------------+---------------+---------------------------+--------------+---------------------------+---------------+----------------+--------------+-----------+------+--------------------+--------+--------------+---------------+-----------------------+---------------+----------+----------+------+------------------------+
# only showing top 20 rows

# %%
display(merged_df_Customer)
# Out:
# StatementMeta(, 2c497fca-bdb2-4efb-b199-544de5641ead, 15, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 21855f51-7538-4701-84ee-147721781dd2)

# %% [markdown]
# # Clean the column name that have different symbols

# %%
def clean_columns(df):
    import re
    new_columns = []
    for c in merged_df_Customer.columns:
        # 1. Remove leading/trailing spaces
        new_c = c.strip()
        # 2. Replace spaces and special characters with underscore
        new_c = re.sub(r'[ ,;{}()\n\t=/$]', '_', new_c)
        # 3. Collapse multiple underscores
        new_c = re.sub(r'_+', '_', new_c)
        # 4. Remove trailing underscores
        new_c = new_c.strip('_')
        new_columns.append(new_c)
    # Rename columns in DataFrame
    for old, new in zip(df.columns, new_columns):
        df = df.withColumnRenamed(old, new)
    return df

merged_df_Customer = clean_columns(merged_df_Customer)
# Out:
# StatementMeta(, 2c497fca-bdb2-4efb-b199-544de5641ead, 16, Finished, Available, Finished)

# %% [markdown]
# # Writing the merged table to the lakehouse table

# %%
merged_df_Customer.write.format("delta").mode("overwrite").saveAsTable("merged_Customer_Silver")
# Out:
# StatementMeta(, 2c497fca-bdb2-4efb-b199-544de5641ead, 17, Finished, Available, Finished)
